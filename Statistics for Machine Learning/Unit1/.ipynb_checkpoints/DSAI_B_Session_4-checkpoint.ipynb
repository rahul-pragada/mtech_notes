# %%
# Probability Distribution

# %%
#Binomial Distribution---Discrete distribution

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
#T shirt example--  for the last 2 years ,Avaerage Defect in the T shirt manufacturing at Allen solly i
#5%

# %%
#i am going to test 20 sample of tshirt
n=20
p=.05
#What is the probability that 3 tshirts are defective from the sample?
x=3
x=np.arange(20)
pval=stats.binom.pmf(x,n,p)

# %%
plt.plot(x,pval,"o--")
plt.xticks(x)
plt.show()

# %%
#What is the probability that maximum of 3 tshirts defective?
stats.binom.pmf(0,n,p)+stats.binom.pmf(1,n,p)+stats.binom.pmf(2,n,p)+stats.binom.pmf(3,n,p)
# Out:
# 0.9840984739802363

# %%
stats.binom.cdf(3,n,p)
# Out:
# 0.9840984739802364

# %%
# Poisson
#In evry 15Km we have an average of 3 restaurant availabe, what is teh prob that 0,1,2,3,4,5 restaurant in 15km?

# %%
x=[0,1,2,3,4,5]
lambd=3

# %%
pval_p=stats.poisson.pmf(x,lambd)

# %%
plt.plot(x,pval_p,"o--")
plt.xticks(x)
plt.show()

# %%
# The avearge weigh of the good day is biscut is 125g with SD of 2.5g, 
# what is the probability that teh weight of the good day biscuit is less than 120g?

# %%
x=120
me=125
sd=2.5
xscale= (x-me)/sd
xscale
# Out:
# -2.0

# %%
stats.norm.cdf(xscale)
# Out:
# 0.022750131948179195

# %%
# what is the probability that teh weight of the good day biscuit is greater 130g?

# %%
x=130
me=125
sd=2.5
xscale= (x-me)/sd
xscale
# Out:
# 2.0

# %%
1-stats.norm.cdf(xscale)
# Out:
# 0.02275013194817921

# %%
# central limit theorm
w=np.random.randn(85000)

# %%
sns.distplot(w)
# Out:
# C:\Users\rajal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
w.max(),w.min()
# Out:
# (4.29069029510964, -4.539054283532185)

# %%
w
# Out:
# array([-0.70732469, -0.37335954, -1.08185064, ...,  1.49440287,
#        -0.02349408, -0.99699783])

# %%
me=3
sd=0.5

# %%
w_pop=(w*sd)+me

# %%
w_pop
# Out:
# array([2.64633765, 2.81332023, 2.45907468, ..., 3.74720144, 2.98825296,
#        2.50150108])

# %%
w_pop.min(),w_pop.max()
# Out:
# (0.7304728582339073, 5.145345147554821)

# %%
sns.boxplot(w_pop)
# Out:
# C:\Users\rajal\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
# classical method
t=[]
for itr in np.arange(200):
    
    samp=[]
    for i in np.arange(500):
        samp.append(np.random.choice(w_pop))
    t.append(np.mean(samp))

# %%
len(t)
# Out:
# 200

# %%
np.array(t).mean()
# Out:
# 3.0001711260733965

# %%
sns.distplot(t)
# Out:
# C:\Users\rajal\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>
