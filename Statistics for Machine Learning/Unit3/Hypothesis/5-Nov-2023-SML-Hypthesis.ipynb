# %% [markdown]
# SML 21-Oct-2023
# DSAI_B_Session_4.ipynb
#
# Population
# Sample - Inferential statistics
#
# Classical - taking data from different areas of population - amount of data is proportional to accurate results
#
# Interval estimations???
#
# Normal distribution
# 1 sigma = 68.3
# 2 sigma = 95.5
# 3 sigma = 99.7
# 1.96𝜎 = 95% is general standard but may not be applicable in all cases, Most of the times 95% standard is used
#
#
# Confidence interval = Given with some evidence
#
# Practical -
# Standard error =. Sample Standard Deviation / √n
#   where ’n’ is number of samples
#
# Estimations are made based on standard error in Practical
#
# Hypothesis :
#
# Null Hypothesis  -H₀
# No Effect
#
# Alternate Hypothesis -  Ha - (Effect - Research Hypothesis which has effect)
#
# Probability value - Evidence  value
# If p < 0.05  —> Reject the null hypothesis i.e at least have 5% of the confidence must be there to reject the null hypothesis
# If P > 0.05  —> Failed to reject (not accept) the null hypothesis
#
# One tail
# Drug < 5 min
# Drug > 5 min
#
# 2 tails (to test both sides of equal
# =
#
# !=
#
# Sample test
#
# One Sample test - Considering only Single numerical test, 1 tail, 2 tail test
#
# 2 Sample test - 2 Columns 1 Numerical & 1 Categorical columns to be considered.
#
# <5 Ha
# Alternate hypothesis will be true if anything is less than -1.96 or more than 1.96 can be rejected and go with Ha.
#
#
# Population
#
# Sample - inference - Hypothesis
#
# Multile samples vs one sample
#
# Null and alternate hypothesis.
#
# effect is alternative
#
# % confidence to accept the null,  0.01%
#
# Sample T test
#
# One sample t Test - 1 Numerical feature - 1 tail, 2 tails, p - Value, Stack value, Z value
#
# glass door
