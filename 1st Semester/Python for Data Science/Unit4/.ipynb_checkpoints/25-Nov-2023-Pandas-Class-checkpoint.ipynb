# %% [markdown]
# #####
# 1D - Series
#
# 2D - DataFrame
#
# 3d - pandas - Panel dataset

# %%
import pandas as pd

# %%
data= [1,2,3,4]

# %%
type(data)
# Out:
# list

# %% [markdown]
# Converting list to Series

# %%
s=pd.Series(data)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Giving customized Index

# %%
s1 = pd.Series(data,index=['a','b','c','d'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# Data Frame s - 2D labelled data with columsn of different data types.

# %%
df= pd. DataFrame(data) #Series to data frame. Column name '0' Introduced

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %% [markdown]
# Dictionary to Data frame

# %%
d = {'fruit': ['Apple','Orange'], 'cost': [10,20]}

# %%
d
# Out:
# {'fruit': ['Apple', 'Orange'], 'cost': [10, 20]}

# %%
type(d)
# Out:
# dict

# %%
df1= pd.DataFrame(d) #Tabular format

# %%
df1
# Out:
#     fruit  cost
# 0   Apple    10
# 1  Orange    20

# %% [markdown]
# ### Operations in Pandas

# %% [markdown]
# merge and join operations
#
# Merge is with respoect to index values whereas join is with respect to the attributes

# %%
player = ['p1','p2','p3']
points = [8,9,5]
title = ['g1','g2','g3']

# %%
df5 = pd.DataFrame({'Name': player, 'points':points, 'Game': title})

# %%
df5
# Out:
#   Name  points Game
# 0   p1       8   g1
# 1   p2       9   g2
# 2   p3       5   g3

# %%
player = ['p1','p5','p6']
power = ['punch','run','kick']
title = ['g1','g5','g6']

# %%
df6 = pd.DataFrame({'Name': player, 'skills':power, 'Game': title})

# %%
df6
# Out:
#   Name skills Game
# 0   p1  punch   g1
# 1   p5    run   g5
# 2   p6   kick   g6

# %% [markdown]
# Merge
#
# Syntax: merge(data, on='col', how='i,o,r,l')

# %%
df5.merge(df6, on = 'Name', how='inner')
# Out:
#   Name  points Game_x skills Game_y
# 0   p1       8     g1  punch     g1

# %%
df5.merge(df6, on = 'Name', how='outer')
#here NaN - represent Not a Number
# Out:
#   Name  points Game_x skills Game_y
# 0   p1     8.0     g1  punch     g1
# 1   p2     9.0     g2    NaN    NaN
# 2   p3     5.0     g3    NaN    NaN
# 3   p5     NaN    NaN    run     g5
# 4   p6     NaN    NaN   kick     g6

# %%
df5.merge(df6, on = 'Name', how='right')
# Out:
#   Name  points Game_x skills Game_y
# 0   p1     8.0     g1  punch     g1
# 1   p5     NaN    NaN    run     g5
# 2   p6     NaN    NaN   kick     g6

# %%
df5.merge(df6, on = 'Name', how='left')
# Out:
#   Name  points Game_x skills Game_y
# 0   p1       8     g1  punch     g1
# 1   p2       9     g2    NaN    NaN
# 2   p3       5     g3    NaN    NaN

# %% [markdown]
# Join
#
# Syntax: table1.join(table2, lsuffix= '', rsuffic='')

# %%
df5
# Out:
#   Name  points Game
# 0   p1       8   g1
# 1   p2       9   g2
# 2   p3       5   g3

# %%
df6
# Out:
#   Name skills Game
# 0   p1  punch   g1
# 1   p5    run   g5
# 2   p6   kick   g6

# %%
df5.join(df6, how = 'inner', lsuffix = '_LT', rsuffix='_RT')
#Got to see why it is not working, it is supposed to work similar to merge
# Out:
#   Name_LT  points Game_LT Name_RT skills Game_RT
# 0      p1       8      g1      p1  punch      g1
# 1      p2       9      g2      p5    run      g5
# 2      p3       5      g3      p6   kick      g6

# %%
df5.join(df6, how = 'outer', lsuffix = '_LT', rsuffix='_RT')
# Out:
#   Name_LT  points Game_LT Name_RT skills Game_RT
# 0      p1       8      g1      p1  punch      g1
# 1      p2       9      g2      p5    run      g5
# 2      p3       5      g3      p6   kick      g6

# %%
df5.join(df6, how = 'right', lsuffix = '_LT', rsuffix='_RT')
# Out:
#   Name_LT  points Game_LT Name_RT skills Game_RT
# 0      p1       8      g1      p1  punch      g1
# 1      p2       9      g2      p5    run      g5
# 2      p3       5      g3      p6   kick      g6

# %%
df5.join(df6, how = 'left', lsuffix = '_LT', rsuffix='_RT')
# Out:
#   Name_LT  points Game_LT Name_RT skills Game_RT
# 0      p1       8      g1      p1  punch      g1
# 1      p2       9      g2      p5    run      g5
# 2      p3       5      g3      p6   kick      g6

# %% [markdown]
# Iteration in dataframes

# %%
import pandas as pd
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Method 1

# %%
for i in df5.index:
    print(df5['Name'][i],df5['points'][i],)
# Out:
# p1 8
# p2 9
# p3 5

# %% [markdown]
# Method 2 is loc

# %%
for i in range(len(df5)):
    print(df5.loc[i,"Name"],df5.loc[i,"points"])
# Out:
# p1 8
# p2 9
# p3 5

# %% [markdown]
# Method 3 using iloc

# %%
for i in range(len(df5)):
    print(df5.iloc[i,0],df5.iloc[i,1])
# Out:
# p1 8
# p2 9
# p3 5

# %%
for index, rows in df5.iterrows():
    print(df5.loc[i,"Name"],df5.loc[i,"points"])
# Out:
# p3 5
# p3 5
# p3 5

# %% [markdown]
# slicing - Just in class experiment to split the train and test data

# %%
rows, columns = df5.shape

# %%
type(rows)
# Out:
# int

# %%
rows
# Out:
# 3

# %%
train = 0.8
train_index = int(float(rows)*train)

# %%
print(df5.iloc[:train_index,:])
# Out:
#   Name  points Game
# 0   p1       8   g1
# 1   p2       9   g2

# %%
print(df5.iloc[train_index:,:])
# Out:
#   Name  points Game
# 2   p3       5   g3

# %% [markdown]
# Reading the dataset

# %%
cars_df=pd.read_csv("cars.csv")
cars_df
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 1                   140                143               202
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 1               Front-wheel drive
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# ...                           ...
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# ...                                              ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                          True                                           6
# 1                          True                                           6
# 2                          True                                           6
# 3                          True                                           6
# 4                          True                                           6
# ...                         ...                                         ...
# 5071                       True                                           5
# 5072                       True                                           6
# 5073                       True                                           6
# 5074                       True                                           6
# 5075                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 1     6 Speed Automatic Select Shift                         22
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 4     6 Speed Automatic Select Shift                         21
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 1                      Gasoline                            28
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 4                      Gasoline                            28
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 1           Automatic transmission                      2009 Audi A3 2.0 T AT
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 4           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 1                   Audi                      2009 Audi A3
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 4                   Audi                      2009 Audi A3
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 1                    2009                                              200
# 2                    2009                                              200
# 3                    2009                                              200
# 4                    2009                                              200
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque
# 0                                             236
# 1                                             207
# 2                                             207
# 3                                             207
# 4                                             207
# ...                                           ...
# 5071                                          253
# 5072                                          398
# 5073                                          398
# 5074                                          330
# 5075                                          330
#
# [5076 rows x 18 columns]

# %%
cars_df.head(10)
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
# 5                 91                 17                62
# 6                 91                 17                62
# 7                201                221               191
# 8                201                221               191
# 9                147                 96                34
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 5              All-wheel drive         Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 6              All-wheel drive         Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 7              All-wheel drive        Audi 4.2L 8 cylinder 350 hp 325 ft-lbs
# 8              All-wheel drive         Audi 3.6L 6 cylinder 280hp 266 ft-lbs
# 9              All-wheel drive  Audi 2.0L 4 cylinder 211 hp 258 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# 1                       True                                           6
# 2                       True                                           6
# 3                       True                                           6
# 4                       True                                           6
# 5                       True                                           6
# 6                       True                                           6
# 7                       True                                           6
# 8                       True                                           6
# 9                       True                                           6
#
#   Engine Information.Transmission  Fuel Information.City mpg  \
# 0  6 Speed Automatic Select Shift                         18
# 1  6 Speed Automatic Select Shift                         22
# 2                  6 Speed Manual                         21
# 3  6 Speed Automatic Select Shift                         21
# 4  6 Speed Automatic Select Shift                         21
# 5                  6 Speed Manual                         16
# 6  6 Speed Automatic Select Shift                         17
# 7  6 Speed Automatic Select Shift                         13
# 8  6 Speed Automatic Select Shift                         14
# 9                  6 Speed Manual                         22
#
#   Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                   Gasoline                            25
# 1                   Gasoline                            28
# 2                   Gasoline                            30
# 3                   Gasoline                            28
# 4                   Gasoline                            28
# 5                   Gasoline                            27
# 6                   Gasoline                            26
# 7                   Gasoline                            18
# 8                   Gasoline                            20
# 9                   Gasoline                            30
#
#   Identification.Classification                 Identification.ID  \
# 0        Automatic transmission                  2009 Audi A3 3.2
# 1        Automatic transmission             2009 Audi A3 2.0 T AT
# 2           Manual transmission                2009 Audi A3 2.0 T
# 3        Automatic transmission        2009 Audi A3 2.0 T Quattro
# 4        Automatic transmission        2009 Audi A3 2.0 T Quattro
# 5           Manual transmission                  2009 Audi A5 3.2
# 6        Automatic transmission               2009 Audi A5 3.2 AT
# 7        Automatic transmission                  2009 Audi Q7 4.2
# 8        Automatic transmission                  2009 Audi Q7 3.6
# 9           Manual transmission  2009 Audi A4 Sedan 2.0 T Quattro
#
#   Identification.Make Identification.Model Year  Identification.Year  \
# 0                Audi              2009 Audi A3                 2009
# 1                Audi              2009 Audi A3                 2009
# 2                Audi              2009 Audi A3                 2009
# 3                Audi              2009 Audi A3                 2009
# 4                Audi              2009 Audi A3                 2009
# 5                Audi              2009 Audi A5                 2009
# 6                Audi              2009 Audi A5                 2009
# 7                Audi              2009 Audi Q7                 2009
# 8                Audi              2009 Audi Q7                 2009
# 9                Audi        2009 Audi A4 Sedan                 2009
#
#    Engine Information.Engine Statistics.Horsepower  \
# 0                                              250
# 1                                              200
# 2                                              200
# 3                                              200
# 4                                              200
# 5                                              265
# 6                                              265
# 7                                              350
# 8                                              280
# 9                                              211
#
#    Engine Information.Engine Statistics.Torque
# 0                                          236
# 1                                          207
# 2                                          207
# 3                                          207
# 4                                          207
# 5                                          243
# 6                                          243
# 7                                          325
# 8                                          266
# 9                                          258

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5076 entries, 0 to 5075
# Data columns (total 18 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Dimensions.Height                                5076 non-null   int64
#  1   Dimensions.Length                                5076 non-null   int64
#  2   Dimensions.Width                                 5076 non-null   int64
#  3   Engine Information.Driveline                     5076 non-null   object
#  4   Engine Information.Engine Type                   5076 non-null   object
#  5   Engine Information.Hybrid                        5076 non-null   bool
#  6   Engine Information.Number of Forward Gears       5076 non-null   int64
#  7   Engine Information.Transmission                  5076 non-null   object
#  8   Fuel Information.City mpg                        5076 non-null   int64
#  9   Fuel Information.Fuel Type                       5076 non-null   object
#  10  Fuel Information.Highway mpg                     5076 non-null   int64
#  11  Identification.Classification                    5076 non-null   object
#  12  Identification.ID                                5076 non-null   object
#  13  Identification.Make                              5076 non-null   object
#  14  Identification.Model Year                        5076 non-null   object
#  15  Identification.Year                              5076 non-null   int64
#  16  Engine Information.Engine Statistics.Horsepower  5076 non-null   int64
#  17  Engine Information.Engine Statistics.Torque      5076 non-null   int64
# dtypes: bool(1), int64(9), object(8)
# memory usage: 679.2+ KB

# %% [markdown]
# ## Indexing and slicing the dataframes

# %% [markdown]
# #### Selecting the data Using Labels: Column Headings

# %% [markdown]
# We use squard brackets [] to select a subset of a python object. For example, we can select all of data from a column
# name Dimensions. HEight from the cars_Df DataFrame by name:

# %%
cars_df[('Dimensions.Height']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Dimensions.Height', 'Identification.Make')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 cars_df[('Dimensions.Height','Identification.Make')]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: ('Dimensions.Height', 'Identification.Make')

# %%
cars_df[2::] # from 2nd row til end.
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 2                   140                143               202
# 3                   140                143               202
# 4                   140                143               202
# 5                    91                 17                62
# 6                    91                 17                62
# ...                 ...                ...               ...
# 5071                 13                253               201
# 5072                141                249               108
# 5073                160                249               108
# 5074                200                210               110
# 5075                200                 94               110
#
#      Engine Information.Driveline  \
# 2               Front-wheel drive
# 3                 All-wheel drive
# 4                 All-wheel drive
# 5                 All-wheel drive
# 6                 All-wheel drive
# ...                           ...
# 5071            Front-wheel drive
# 5072              All-wheel drive
# 5073              All-wheel drive
# 5074             Rear-wheel drive
# 5075             Rear-wheel drive
#
#                       Engine Information.Engine Type  \
# 2       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 5              Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 6              Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# ...                                              ...
# 5071         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5072  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
# 5074      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
# 5075      BMW 3.0L 6 cylinder 315hp 330 ft-lbs Turbo
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 2                          True                                           6
# 3                          True                                           6
# 4                          True                                           6
# 5                          True                                           6
# 6                          True                                           6
# ...                         ...                                         ...
# 5071                       True                                           5
# 5072                       True                                           6
# 5073                       True                                           6
# 5074                       True                                           6
# 5075                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 2                     6 Speed Manual                         21
# 3     6 Speed Automatic Select Shift                         21
# 4     6 Speed Automatic Select Shift                         21
# 5                     6 Speed Manual                         16
# 6     6 Speed Automatic Select Shift                         17
# ...                              ...                        ...
# 5071               5 Speed Automatic                         18
# 5072                  6 Speed Manual                         12
# 5073                  6 Speed Manual                         12
# 5074  6 Speed Automatic Select Shift                         17
# 5075  6 Speed Automatic Select Shift                         17
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 2                      Gasoline                            30
# 3                      Gasoline                            28
# 4                      Gasoline                            28
# 5                      Gasoline                            27
# 6                      Gasoline                            26
# ...                         ...                           ...
# 5071                   Gasoline                            25
# 5072                   Gasoline                            20
# 5073                   Gasoline                            20
# 5074                   Gasoline                            25
# 5075                   Gasoline                            25
#
#      Identification.Classification                          Identification.ID  \
# 2              Manual transmission                         2009 Audi A3 2.0 T
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 4           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 5              Manual transmission                           2009 Audi A5 3.2
# 6           Automatic transmission                        2009 Audi A5 3.2 AT
# ...                            ...                                        ...
# 5071        Automatic transmission                      2012 Honda Pilot EX-L
# 5072           Manual transmission   2012 Lamborghini Gallardo Coupe LP 560-4
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
# 5074        Automatic transmission                        2012 BMW 740i Sedan
# 5075        Automatic transmission                       2012 BMW 740Li Sedan
#
#      Identification.Make         Identification.Model Year  \
# 2                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 4                   Audi                      2009 Audi A3
# 5                   Audi                      2009 Audi A5
# 6                   Audi                      2009 Audi A5
# ...                  ...                               ...
# 5071               Honda                  2012 Honda Pilot
# 5072         Lamborghini    2012 Lamborghini Gallardo Coup
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
# 5074                 BMW                 2012 BMW 7 Series
# 5075                 BMW                 2012 BMW 7 Series
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 2                    2009                                              200
# 3                    2009                                              200
# 4                    2009                                              200
# 5                    2009                                              265
# 6                    2009                                              265
# ...                   ...                                              ...
# 5071                 2012                                              250
# 5072                 2012                                              552
# 5073                 2012                                              552
# 5074                 2012                                              315
# 5075                 2012                                              315
#
#       Engine Information.Engine Statistics.Torque
# 2                                             207
# 3                                             207
# 4                                             207
# 5                                             243
# 6                                             243
# ...                                           ...
# 5071                                          253
# 5072                                          398
# 5073                                          398
# 5074                                          330
# 5075                                          330
#
# [5074 rows x 18 columns]

# %%
cars_df[::3] # every 3rd row
# Out:
#       Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                   140                143               202
# 3                   140                143               202
# 6                    91                 17                62
# 9                   147                 96                34
# 12                  172                 63                87
# ...                 ...                ...               ...
# 5061                244                  8               158
# 5064                201                 33               219
# 5067                  3                253               201
# 5070                  3                253               201
# 5073                160                249               108
#
#      Engine Information.Driveline  \
# 0                 All-wheel drive
# 3                 All-wheel drive
# 6                 All-wheel drive
# 9                 All-wheel drive
# 12              Front-wheel drive
# ...                           ...
# 5061            Front-wheel drive
# 5064            Front-wheel drive
# 5067            Front-wheel drive
# 5070             Four-wheel drive
# 5073              All-wheel drive
#
#                       Engine Information.Engine Type  \
# 0               Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 3       Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 6              Audi 3.2L 6 cylinder 265hp 243 ft-lbs
# 9       Audi 2.0L 4 cylinder 211 hp 258 ft-lbs Turbo
# 12           Acura 3.5L 6 Cylinder 280 hp 254 ft-lbs
# ...                                              ...
# 5061         Honda 1.5L 4 Cylinder 117 hp 106 ft-lbs
# 5064         Honda 3.5L 6 Cylinder 248 hp 250 ft-lbs
# 5067         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5070         Honda 3.5L 6 Cylinder 250 hp 253 ft-lbs
# 5073  Lamborghini 5.2L 10 cylinder 552 hp 398 ft-lbs
#
#       Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                          True                                           6
# 3                          True                                           6
# 6                          True                                           6
# 9                          True                                           6
# 12                         True                                           6
# ...                         ...                                         ...
# 5061                       True                                           5
# 5064                       True                                           6
# 5067                       True                                           5
# 5070                       True                                           5
# 5073                       True                                           6
#
#      Engine Information.Transmission  Fuel Information.City mpg  \
# 0     6 Speed Automatic Select Shift                         18
# 3     6 Speed Automatic Select Shift                         21
# 6     6 Speed Automatic Select Shift                         17
# 9                     6 Speed Manual                         22
# 12    6 Speed Automatic Select Shift                         20
# ...                              ...                        ...
# 5061  5 Speed Automatic Select Shift                         27
# 5064               6 Speed Automatic                         19
# 5067               5 Speed Automatic                         18
# 5070               5 Speed Automatic                         17
# 5073                  6 Speed Manual                         12
#
#      Fuel Information.Fuel Type  Fuel Information.Highway mpg  \
# 0                      Gasoline                            25
# 3                      Gasoline                            28
# 6                      Gasoline                            26
# 9                      Gasoline                            30
# 12                     Gasoline                            29
# ...                         ...                           ...
# 5061                   Gasoline                            33
# 5064                   Gasoline                            28
# 5067                   Gasoline                            25
# 5070                   Gasoline                            24
# 5073                   Gasoline                            20
#
#      Identification.Classification                          Identification.ID  \
# 0           Automatic transmission                           2009 Audi A3 3.2
# 3           Automatic transmission                 2009 Audi A3 2.0 T Quattro
# 6           Automatic transmission                        2009 Audi A5 3.2 AT
# 9              Manual transmission           2009 Audi A4 Sedan 2.0 T Quattro
# 12          Automatic transmission                              2012 Acura TL
# ...                            ...                                        ...
# 5061        Automatic transmission                    2012 Honda Fit Sport AT
# 5064        Automatic transmission                 2012 Honda Odyssey Touring
# 5067        Automatic transmission                        2012 Honda Pilot LX
# 5070        Automatic transmission                    2012 Honda Pilot EX 4WD
# 5073           Manual transmission  2012 Lamborghini Gallardo LP 560-4 Spyder
#
#      Identification.Make         Identification.Model Year  \
# 0                   Audi                      2009 Audi A3
# 3                   Audi                      2009 Audi A3
# 6                   Audi                      2009 Audi A5
# 9                   Audi                2009 Audi A4 Sedan
# 12                 Acura                     2012 Acura TL
# ...                  ...                               ...
# 5061               Honda                    2012 Honda Fit
# 5064               Honda                2012 Honda Odyssey
# 5067               Honda                  2012 Honda Pilot
# 5070               Honda                  2012 Honda Pilot
# 5073         Lamborghini  2012 Lamborghini Gallardo Spyder
#
#       Identification.Year  Engine Information.Engine Statistics.Horsepower  \
# 0                    2009                                              250
# 3                    2009                                              200
# 6                    2009                                              265
# 9                    2009                                              211
# 12                   2012                                              280
# ...                   ...                                              ...
# 5061                 2012                                              117
# 5064                 2012                                              248
# 5067                 2012                                              250
# 5070                 2012                                              250
# 5073                 2012                                              552
#
#       Engine Information.Engine Statistics.Torque
# 0                                             236
# 3                                             207
# 6                                             243
# 9                                             258
# 12                                            254
# ...                                           ...
# 5061                                          106
# 5064                                          250
# 5067                                          253
# 5070                                          253
# 5073                                          398
#
# [1692 rows x 18 columns]

# %%
cars_df.iloc[0:3,2:5] #1st one for rwo and 2nd set is for column ... Slicing
# Out:
#    Dimensions.Width Engine Information.Driveline  \
# 0               202              All-wheel drive
# 1               202            Front-wheel drive
# 2               202            Front-wheel drive
#
#                  Engine Information.Engine Type
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo

# %%
cars_df.iloc[[0, 3],2:5] # 0th and 3rd row display of given column
# Out:
#    Dimensions.Width Engine Information.Driveline  \
# 0               202              All-wheel drive
# 3               202              All-wheel drive
#
#                  Engine Information.Engine Type
# 0          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 3  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo

# %%
cars_df2= cars_df.copy() # Copy Dataframe

# %%
#rename columns.

# %% [markdown]
# ### Subsetting Data using Criteria

# %% [markdown]
# ### Arthmetic Operations

# %% [markdown]
# cars_Df2('column1'+'column2')

# %% [markdown]
# #### Sort

# %% [markdown]
# Filtering Data --- use >= or <= directly on column

# %% [markdown]
# logical operations can be applied on top of filtering condictions

# %%
df5
# Out:
#   Name  points Game
# 0   p1       8   g1
# 1   p2       9   g2
# 2   p3       5   g3

# %%
anothercolumn = [1,2,3]

# %%
df5['additionalcolumn'] = anothercolumn

# %%
df5
# Out:
#   Name  points Game  additionalcolumn
# 0   p1       8   g1                 1
# 1   p2       9   g2                 2
# 2   p3       5   g3                 3
