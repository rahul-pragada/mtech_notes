# %% [markdown]
# **Load the library (1 mark)**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Open the csv file (1 mark)**

# %%
df_cancer = pd.read_csv('cancer.csv')

# %% [markdown]
# **Display the top 5 rows (1 mark)**

# %%
df_cancer.head()
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
#    Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0            4                    2         2                      3
# 1            3                    7         8                      6
# 2            7                    9         2                      1
# 3            2                    3         1                      4
# 4            2                    4         1                      4
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring   Level
# 0                         1              2          3        4     Low
# 1                         2              1          7        2  Medium
# 2                         4              6          7        2    High
# 3                         5              6          7        5    High
# 4                         2              4          2        3    High
#
# [5 rows x 26 columns]

# %% [markdown]
# **Display column information of the dataframe (1 mark)**

# %%
df_cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
#  14  Chest Pain                1000 non-null   int64
#  15  Coughing of Blood         1000 non-null   int64
#  16  Fatigue                   1000 non-null   int64
#  17  Weight Loss               1000 non-null   int64
#  18  Shortness of Breath       1000 non-null   int64
#  19  Wheezing                  1000 non-null   int64
#  20  Swallowing Difficulty     1000 non-null   int64
#  21  Clubbing of Finger Nails  1000 non-null   int64
#  22  Frequent Cold             1000 non-null   int64
#  23  Dry Cough                 1000 non-null   int64
#  24  Snoring                   1000 non-null   int64
#  25  Level                     1000 non-null   object
# dtypes: int64(24), object(2)
# memory usage: 203.3+ KB

# %% [markdown]
# **Display statistics information (1 mark)**

# %%
df_cancer.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# std        1.980833              2.107805      2.126999              1.848518
# min        1.000000              1.000000      1.000000              1.000000
# 25%        4.000000              3.000000      2.000000              3.000000
# 50%        6.000000              5.000000      5.000000              4.000000
# 75%        7.000000              7.000000      7.000000              6.000000
# max        8.000000              8.000000      7.000000              7.000000
#
#        Balanced Diet  ...  Coughing of Blood      Fatigue  Weight Loss  \
# count    1000.000000  ...        1000.000000  1000.000000  1000.000000
# mean        4.491000  ...           4.859000     3.856000     3.855000
# std         2.135528  ...           2.427965     2.244616     2.206546
# min         1.000000  ...           1.000000     1.000000     1.000000
# 25%         2.000000  ...           3.000000     2.000000     2.000000
# 50%         4.000000  ...           4.000000     3.000000     3.000000
# 75%         7.000000  ...           7.000000     5.000000     6.000000
# max         7.000000  ...           9.000000     9.000000     8.000000
#
#        Shortness of Breath     Wheezing  Swallowing Difficulty  \
# count          1000.000000  1000.000000            1000.000000
# mean              4.240000     3.777000               3.746000
# std               2.285087     2.041921               2.270383
# min               1.000000     1.000000               1.000000
# 25%               2.000000     2.000000               2.000000
# 50%               4.000000     4.000000               4.000000
# 75%               6.000000     5.000000               5.000000
# max               9.000000     8.000000               8.000000
#
#        Clubbing of Finger Nails  Frequent Cold    Dry Cough      Snoring
# count               1000.000000    1000.000000  1000.000000  1000.000000
# mean                   3.923000       3.536000     3.853000     2.926000
# std                    2.388048       1.832502     2.039007     1.474686
# min                    1.000000       1.000000     1.000000     1.000000
# 25%                    2.000000       2.000000     2.000000     2.000000
# 50%                    4.000000       3.000000     4.000000     3.000000
# 75%                    5.000000       5.000000     6.000000     4.000000
# max                    9.000000       7.000000     7.000000     7.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# **Check for null values (1 mark)**

# %%
df_cancer.isnull().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# **Display the column names (1 mark)**

# %%
df_cancer.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %% [markdown]
# **Display the unique value of Level column (1 mark)**

# %%
df_cancer.Level.unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %% [markdown]
# **Convert the column Level from categorical type to numerical type (1 mark)**

# %%
df_cancer['Level'].replace(['High', 'Medium' , 'Low'],
                        [1, 2, 3], inplace=True)

df_cancer['Patient Id'] = pd.to_numeric(df_cancer['Level'], errors = 'coerce')
# check the missing values 
df_cancer['Patient Id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Import the vizualization library (1 mark)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Display cor-relation matrix (1 mark)**

# %%
plt.figure(figsize=(12,8))
df_cancer.corr()
#sns.heatmap(df_cancer.corr(), annot = True, cmap = 'Blues')
# Out:
#                              index  Patient Id       Age    Gender  \
# index                     1.000000   -0.057758  0.002674 -0.025739
# Patient Id               -0.057758    1.000000 -0.060048  0.164985
# Age                       0.002674   -0.060048  1.000000 -0.202086
# Gender                   -0.025739    0.164985 -0.202086  1.000000
# Air Pollution             0.053307   -0.636038  0.099494 -0.246912
# Alcohol use               0.041374   -0.718710  0.151742 -0.227636
# Dust Allergy              0.037960   -0.713839  0.035202 -0.204312
# OccuPational Hazards      0.032355   -0.673255  0.062177 -0.192343
# Genetic Risk              0.030725   -0.701303  0.073151 -0.222727
# chronic Lung Disease      0.025177   -0.609971  0.128952 -0.205061
# Balanced Diet             0.030743   -0.706273  0.004863 -0.099741
# Obesity                   0.050584   -0.827435  0.034337 -0.123813
# Smoking                   0.018407   -0.519530  0.075333 -0.206924
# Passive Smoker            0.019517   -0.703594  0.004908 -0.184826
# Chest Pain                0.022210   -0.645461  0.012864 -0.218426
# Coughing of Blood         0.049401   -0.782092  0.053006 -0.146505
# Fatigue                   0.042346   -0.625114  0.095059 -0.116467
# Weight Loss               0.026393   -0.352738  0.106946 -0.057993
# Shortness of Breath       0.027950   -0.497024  0.035329 -0.045972
# Wheezing                  0.015078   -0.242794 -0.095354 -0.076304
# Swallowing Difficulty     0.005573   -0.249142 -0.105833 -0.058324
# Clubbing of Finger Nails  0.015706   -0.280063  0.039258 -0.034219
# Frequent Cold             0.045687   -0.444017 -0.012706 -0.000526
# Dry Cough                 0.003793   -0.373968  0.012128 -0.123001
# Snoring                  -0.002957   -0.289366 -0.004700 -0.181618
# Level                    -0.057758    1.000000 -0.060048  0.164985
#
#                           Air Pollution  Alcohol use  Dust Allergy  \
# index                          0.053307     0.041374      0.037960
# Patient Id                    -0.636038    -0.718710     -0.713839
# Age                            0.099494     0.151742      0.035202
# Gender                        -0.246912    -0.227636     -0.204312
# Air Pollution                  1.000000     0.747293      0.637503
# Alcohol use                    0.747293     1.000000      0.818644
# Dust Allergy                   0.637503     0.818644      1.000000
# OccuPational Hazards           0.608924     0.878786      0.835860
# Genetic Risk                   0.705276     0.877210      0.787904
# chronic Lung Disease           0.626701     0.763576      0.619556
# Balanced Diet                  0.524873     0.653352      0.647197
# Obesity                        0.601468     0.669312      0.700676
# Smoking                        0.481902     0.547035      0.358691
# Passive Smoker                 0.606764     0.592576      0.560002
# Chest Pain                     0.585734     0.717242      0.639983
# Coughing of Blood              0.607829     0.667612      0.625291
# Fatigue                        0.211724     0.237245      0.332472
# Weight Loss                    0.258016     0.207851      0.321756
# Shortness of Breath            0.269558     0.435785      0.518682
# Wheezing                       0.055368     0.180817      0.304850
# Swallowing Difficulty         -0.080918    -0.114073      0.031141
# Clubbing of Finger Nails       0.241065     0.414992      0.345714
# Frequent Cold                  0.174539     0.180778      0.219389
# Dry Cough                      0.261489     0.211277      0.300195
# Snoring                       -0.021343     0.122694      0.052844
# Level                         -0.636038    -0.718710     -0.713839
#
#                           OccuPational Hazards  Genetic Risk  \
# index                                 0.032355      0.030725
# Patient Id                           -0.673255     -0.701303
# Age                                   0.062177      0.073151
# Gender                               -0.192343     -0.222727
# Air Pollution                         0.608924      0.705276
# Alcohol use                           0.878786      0.877210
# Dust Allergy                          0.835860      0.787904
# OccuPational Hazards                  1.000000      0.893049
# Genetic Risk                          0.893049      1.000000
# chronic Lung Disease                  0.858284      0.836231
# Balanced Diet                         0.691509      0.679905
# Obesity                               0.722191      0.729826
# Smoking                               0.497693      0.543259
# Passive Smoker                        0.555311      0.609071
# Chest Pain                            0.775619      0.831751
# Coughing of Blood                     0.645947      0.632236
# Fatigue                               0.267844      0.230530
# Weight Loss                           0.176226      0.271743
# Shortness of Breath                   0.366482      0.458200
# Wheezing                              0.178925      0.204973
# Swallowing Difficulty                -0.002853     -0.062948
# Clubbing of Finger Nails              0.366447      0.357815
# Frequent Cold                         0.077166      0.087092
# Dry Cough                             0.159887      0.194399
# Snoring                               0.022916     -0.056831
# Level                                -0.673255     -0.701303
#
#                           chronic Lung Disease  ...   Fatigue  Weight Loss  \
# index                                 0.025177  ...  0.042346     0.026393
# Patient Id                           -0.609971  ... -0.625114    -0.352738
# Age                                   0.128952  ...  0.095059     0.106946
# Gender                               -0.205061  ... -0.116467    -0.057993
# Air Pollution                         0.626701  ...  0.211724     0.258016
# Alcohol use                           0.763576  ...  0.237245     0.207851
# Dust Allergy                          0.619556  ...  0.332472     0.321756
# OccuPational Hazards                  0.858284  ...  0.267844     0.176226
# Genetic Risk                          0.836231  ...  0.230530     0.271743
# chronic Lung Disease                  1.000000  ...  0.247697     0.104080
# Balanced Diet                         0.622632  ...  0.400678    -0.006544
# Obesity                               0.601754  ...  0.552788     0.313495
# Smoking                               0.578585  ...  0.200029    -0.212937
# Passive Smoker                        0.572698  ...  0.377919     0.058336
# Chest Pain                            0.782646  ...  0.251135    -0.001092
# Coughing of Blood                     0.602987  ...  0.481540     0.105857
# Fatigue                               0.247697  ...  1.000000     0.469517
# Weight Loss                           0.104080  ...  0.469517     1.000000
# Shortness of Breath                   0.182426  ...  0.398625     0.574497
# Wheezing                              0.057214  ...  0.174477     0.331179
# Swallowing Difficulty                 0.007279  ...  0.149562     0.053384
# Clubbing of Finger Nails              0.298023  ...  0.040694     0.376484
# Frequent Cold                         0.028759  ...  0.407915     0.160348
# Dry Cough                             0.114161  ...  0.271167     0.188598
# Snoring                               0.043375  ...  0.231748    -0.189106
# Level                                -0.609971  ... -0.625114    -0.352738
#
#                           Shortness of Breath  Wheezing  \
# index                                0.027950  0.015078
# Patient Id                          -0.497024 -0.242794
# Age                                  0.035329 -0.095354
# Gender                              -0.045972 -0.076304
# Air Pollution                        0.269558  0.055368
# Alcohol use                          0.435785  0.180817
# Dust Allergy                         0.518682  0.304850
# OccuPational Hazards                 0.366482  0.178925
# Genetic Risk                         0.458200  0.204973
# chronic Lung Disease                 0.182426  0.057214
# Balanced Diet                        0.343623  0.063930
# Obesity                              0.406203  0.094287
# Smoking                             -0.023259 -0.047060
# Passive Smoker                       0.062948  0.200283
# Chest Pain                           0.237045  0.107211
# Coughing of Blood                    0.318777 -0.085698
# Fatigue                              0.398625  0.174477
# Weight Loss                          0.574497  0.331179
# Shortness of Breath                  1.000000  0.207564
# Wheezing                             0.207564  1.000000
# Swallowing Difficulty               -0.200477  0.393487
# Clubbing of Finger Nails             0.474275  0.338271
# Frequent Cold                        0.351489  0.098855
# Dry Cough                            0.493331  0.054388
# Snoring                             -0.159291  0.116183
# Level                               -0.497024 -0.242794
#
#                           Swallowing Difficulty  Clubbing of Finger Nails  \
# index                                  0.005573                  0.015706
# Patient Id                            -0.249142                 -0.280063
# Age                                   -0.105833                  0.039258
# Gender                                -0.058324                 -0.034219
# Air Pollution                         -0.080918                  0.241065
# Alcohol use                           -0.114073                  0.414992
# Dust Allergy                           0.031141                  0.345714
# OccuPational Hazards                  -0.002853                  0.366447
# Genetic Risk                          -0.062948                  0.357815
# chronic Lung Disease                   0.007279                  0.298023
# Balanced Diet                          0.046807                  0.041967
# Obesity                                0.127213                  0.149093
# Smoking                                0.236141                 -0.041147
# Passive Smoker                         0.348922                 -0.035536
# Chest Pain                             0.071784                  0.081386
# Coughing of Blood                      0.086289                 -0.066443
# Fatigue                                0.149562                  0.040694
# Weight Loss                            0.053384                  0.376484
# Shortness of Breath                   -0.200477                  0.474275
# Wheezing                               0.393487                  0.338271
# Swallowing Difficulty                  1.000000                 -0.119741
# Clubbing of Finger Nails              -0.119741                  1.000000
# Frequent Cold                          0.132363                  0.242529
# Dry Cough                             -0.055428                  0.307271
# Snoring                                0.210540                 -0.017537
# Level                                 -0.249142                 -0.280063
#
#                           Frequent Cold  Dry Cough   Snoring     Level
# index                          0.045687   0.003793 -0.002957 -0.057758
# Patient Id                    -0.444017  -0.373968 -0.289366  1.000000
# Age                           -0.012706   0.012128 -0.004700 -0.060048
# Gender                        -0.000526  -0.123001 -0.181618  0.164985
# Air Pollution                  0.174539   0.261489 -0.021343 -0.636038
# Alcohol use                    0.180778   0.211277  0.122694 -0.718710
# Dust Allergy                   0.219389   0.300195  0.052844 -0.713839
# OccuPational Hazards           0.077166   0.159887  0.022916 -0.673255
# Genetic Risk                   0.087092   0.194399 -0.056831 -0.701303
# chronic Lung Disease           0.028759   0.114161  0.043375 -0.609971
# Balanced Diet                  0.263931   0.331995  0.152677 -0.706273
# Obesity                        0.288368   0.200618  0.039422 -0.827435
# Smoking                        0.039585   0.010101  0.189055 -0.519530
# Passive Smoker                 0.104553   0.120761  0.247943 -0.703594
# Chest Pain                     0.042937   0.142180  0.140036 -0.645461
# Coughing of Blood              0.244235   0.147659  0.087944 -0.782092
# Fatigue                        0.407915   0.271167  0.231748 -0.625114
# Weight Loss                    0.160348   0.188598 -0.189106 -0.352738
# Shortness of Breath            0.351489   0.493331 -0.159291 -0.497024
# Wheezing                       0.098855   0.054388  0.116183 -0.242794
# Swallowing Difficulty          0.132363  -0.055428  0.210540 -0.249142
# Clubbing of Finger Nails       0.242529   0.307271 -0.017537 -0.280063
# Frequent Cold                  1.000000   0.515918  0.335844 -0.444017
# Dry Cough                      0.515918   1.000000  0.176146 -0.373968
# Snoring                        0.335844   0.176146  1.000000 -0.289366
# Level                         -0.444017  -0.373968 -0.289366  1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# **Display the histogram of the dataframe (2 mark)**

# %%
df_cancer.hist()
# Out:
# array([[<Axes: title={'center': 'index'}>,
#         <Axes: title={'center': 'Patient Id'}>,
#         <Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Air Pollution'}>],
#        [<Axes: title={'center': 'Alcohol use'}>,
#         <Axes: title={'center': 'Dust Allergy'}>,
#         <Axes: title={'center': 'OccuPational Hazards'}>,
#         <Axes: title={'center': 'Genetic Risk'}>,
#         <Axes: title={'center': 'chronic Lung Disease'}>],
#        [<Axes: title={'center': 'Balanced Diet'}>,
#         <Axes: title={'center': 'Obesity'}>,
#         <Axes: title={'center': 'Smoking'}>,
#         <Axes: title={'center': 'Passive Smoker'}>,
#         <Axes: title={'center': 'Chest Pain'}>],
#        [<Axes: title={'center': 'Coughing of Blood'}>,
#         <Axes: title={'center': 'Fatigue'}>,
#         <Axes: title={'center': 'Weight Loss'}>,
#         <Axes: title={'center': 'Shortness of Breath'}>,
#         <Axes: title={'center': 'Wheezing'}>],
#        [<Axes: title={'center': 'Swallowing Difficulty'}>,
#         <Axes: title={'center': 'Clubbing of Finger Nails'}>,
#         <Axes: title={'center': 'Frequent Cold'}>,
#         <Axes: title={'center': 'Dry Cough'}>,
#         <Axes: title={'center': 'Snoring'}>],
#        [<Axes: title={'center': 'Level'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %% [markdown]
# **Display the countplot for Gender at different Level (1 mark)**

# %%
df_cancer = pd.read_csv('cancer.csv')
tab = pd.crosstab(index=df_cancer['Gender'], columns=df_cancer['Level'])
tab
# Out:
# Level   High  Low  Medium
# Gender
# 1        252  149     197
# 2        113  154     135

# %% [markdown]
# **Display the countplot for Gender at different Smoking (1 mark)**

# %%
tab = pd.crosstab(index=df_cancer['Gender'], columns=df_cancer['Smoking'])
tab
# Out:
# Smoking    1    2   3   4   5   6    7   8
# Gender
# 1        102  102  79  49  10  28  167  61
# 2         79  120  93  10   0  32   40  28

# %% [markdown]
# **Display a pie chart the % of different Level (1 mark)**

# %%
df_cancer.Level.value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Display a distribution plot for Level column (1 mark)**

# %%
df_cancer['Level'].replace(['High', 'Medium' , 'Low'],
                        [1, 2, 3], inplace=True)
sns.distplot(df_cancer.Level.value_counts())
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_7108\1494893202.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_cancer.Level.value_counts())
# <Axes: xlabel='count', ylabel='Density'>

# %% [markdown]
# **Display a line plot between Age and Level (1 mark)**

# %%
df_cancer.plot.line(x='Age', y='Level')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# **Display a line plot between Chest Pain and Level (1 mark)**

# %%
df_cancer.plot.line(x='Chest Pain', y='Level')
# Out:
# <Axes: xlabel='Chest Pain'>

# %% [markdown]
# **Display a scatter plot between Smoking and Shortness of Breath w.r.t Level (hue) (1 mark)**

# %%
df_cancer.plot.scatter(x='Smoking',y='Shortness of Breath')
# Out:
# <Axes: xlabel='Smoking', ylabel='Shortness of Breath'>

# %% [markdown]
# **Display a scatter plot between Age and Gender w.r.t Level (hue) (1 mark)**

# %%
#df_cancer.plot.scatter(x='Age',y='Gender')
plt.figure(figsize=(8,4))
sns.scatterplot(data = df_cancer,x='Age',y='Gender', hue='Level', palette=sns.color_palette("Set1", 5))
plt.title("test")
plt.show()
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_7108\861150478.py:3: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.scatterplot(data = df_cancer,x='Age',y='Gender', hue='Level', palette=sns.color_palette("Set1", 5))

# %% [markdown]
# **display a histogram plot between OccuPational Hazards and Gender (1 mark)**

# %%
#df_cancer[['OccuPational Hazards', 'Gender']].hist()
df_cancer.groupby('OccuPational Hazards')['Gender'].value_counts().unstack().plot.bar(ylabel='OccuPational Hazards')
# Out:
# <Axes: xlabel='OccuPational Hazards', ylabel='OccuPational Hazards'>

# %% [markdown]
# **Display a bar plot for obesity and coughing of blood (1 mark)**

# %%
sns.barplot(x='Obesity', y='Coughing of Blood', data=df_cancer)
# Out:
# <Axes: xlabel='Obesity', ylabel='Coughing of Blood'>

# %% [markdown]
# **Display the boxplot for each feature of the dataframe (2 mark)**

# %%
df_cancer = df_cancer.drop(['index'], axis=1)
df_cancer.boxplot()
# Out:
# <Axes: >
